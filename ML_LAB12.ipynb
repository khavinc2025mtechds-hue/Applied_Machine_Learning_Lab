# %%
import pandas as pd
# Load the dataset (replace with your dataset path)
df = pd.read_csv("/content/campaign_responses.csv")
# Inspect the first few rows of the dataset
print(df.head())
# Out:
#    customer_id  age  gender  annual_income  credit_score employed  \
# 0            1   35    Male          65000           720      Yes
# 1            2   28  Female          45000           680       No
# 2            3   42    Male          85000           750      Yes
# 3            4   31  Female          55000           710      Yes
# 4            5   47    Male          95000           790      Yes
#
#   marital_status  no_of_children responded
# 0        Married               2       Yes
# 1         Single               0        No
# 2        Married               3       Yes
# 3         Single               1        No
# 4        Married               2       Yes

# %%
df.isnull().sum()
# Out:
# customer_id       0
# age               0
# gender            0
# annual_income     0
# credit_score      0
# employed          0
# marital_status    0
# no_of_children    0
# responded         0
# dtype: int64

# %%
df.dtypes
# Out:
# customer_id        int64
# age                int64
# gender            object
# annual_income      int64
# credit_score       int64
# employed          object
# marital_status    object
# no_of_children     int64
# responded         object
# dtype: object

# %%
df.describe()
# Out:
#        customer_id        age  annual_income  credit_score  no_of_children
# count    56.000000  56.000000      56.000000     56.000000       56.000000
# mean     28.500000  36.214286   69017.857143    719.107143        1.285714
# std      16.309506   7.088311   22784.756524     60.340753        1.186504
# min       1.000000  25.000000   35000.000000    600.000000        0.000000
# 25%      14.750000  30.000000   48000.000000    677.500000        0.000000
# 50%      28.500000  35.500000   64500.000000    720.000000        1.000000
# 75%      42.250000  42.000000   90000.000000    770.000000        2.000000
# max      56.000000  51.000000  110000.000000    820.000000        3.000000

# %%
# Calculate the correlation matrix for numeric columns only
correlation_matrix = df.select_dtypes(include=['number']).corr()

# %%
# Display the correlation matrix
print(correlation_matrix)
import seaborn as sns
import matplotlib.pyplot as plt
# Set the size of the plot
plt.figure(figsize=(12, 10))
# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
# Title
plt.title('Correlation Matrix')
# Display the plot
plt.show()
# Pair plot to show relationships between new features and target
sns.pairplot(df, hue='responded', vars=['credit_score', 'annual_income', 'age'])
plt.suptitle("Pair Plot of Engineered Features by Response Status", y=1.02)
plt.show()
# Out:
#                 customer_id       age  annual_income  credit_score  \
# customer_id        1.000000  0.038532       0.070627      0.034086
# age                0.038532  1.000000       0.983787      0.970942
# annual_income      0.070627  0.983787       1.000000      0.978764
# credit_score       0.034086  0.970942       0.978764      1.000000
# no_of_children     0.013154  0.932992       0.955499      0.922946
#
#                 no_of_children
# customer_id           0.013154
# age                   0.932992
# annual_income         0.955499
# credit_score          0.922946
# no_of_children        1.000000
